# %% [markdown]
# # Script for Generating Automatic Blacklist Based on a FSQ Dataset

# %%
from sklearn.neighbors import BallTree
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import re
import unicodedata
from collections import defaultdict, Counter
from shapely import wkt
from shapely.geometry import Polygon
from shapely.ops import unary_union
import pandas as pd
import geohash
import nltk
from nltk.corpus import stopwords
from shapely.geometry import Point

# Download stopwords once
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /home/kl877/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Helper Functions

# %%
def tokenize(text):
    """Lowercase, remove punctuation, and split into tokens."""
    words = re.findall(r'\b[a-z]{2,}\b', text.lower())
    return words

def token_distribution_by_geohash(df, geohash_precision=5):
    """ 
    Helper function for [generate_blacklist].
    Produces a DataFrame storing the tokens of all names in [df], 
    along with the global count for each token and the number of regions it appears in.

    Returns the total number of regions the df is partitioned into and the token dataframe
    as a tuple, n_regions, token_df

    Parameters:
        df (FSQ POI DataFrame/GeoDataFrame): must have 'name', 'latitude' and 'longitude' columns.
        geohash_precision (int, optional): must be between 1 (inclusive) and 12 (inclusive). 
        Larger precisions mean smaller partitioning of grids in [df]. The default param is 5.
    """
    df = df.copy()
    
    # Vectorized geohash encoding using zip and list comprehension
    df['geohash'] = [geohash.encode(lat, lon, precision=geohash_precision) 
                     for lat, lon in zip(df['latitude'], df['longitude'])]
    
    # Tokenize names
    df['tokens'] = df['name'].apply(tokenize)  # assumes list of strings

    print(f"Total POIs: {len(df)}")
    
    # Flatten all tokens for global count
    global_token_counts = Counter(token for tokens in df['tokens'] for token in tokens)
    
    # Group by geohash
    geo_token_counts = defaultdict(Counter)
    geo_token_sets = defaultdict(set)

    for geo, tokens in zip(df['geohash'], df['tokens']):
        geo_token_counts[geo].update(tokens)
        geo_token_sets[geo].update(tokens)

    # Now compile final stats
    rows = []
    for token, global_count in global_token_counts.items():
        n_regions = sum(1 for geo in geo_token_counts if token in geo_token_counts[geo])
        # max_local_count = max(
        #     geo_token_counts[geo][token] for geo in geo_token_counts if token in geo_token_counts[geo]
        # )
        rows.append({
            'token': token,
            'global_count': global_count,
            'n_regions': n_regions
            # 'max_local_count': max_local_count
        })

    token_df = pd.DataFrame(rows)
    n_unique_regions = df['geohash'].nunique()
    
    return n_unique_regions, token_df.sort_values(by='global_count', ascending=False)

def generate_blacklist(gdf, geohash_precision=5, file_path = None):
    """ 
    Creates a list of globally common and widespread words found from names in [gdf].

    Parameters:
        gdf (GeoDataFrame): contains tokens and their global counts and number of regions appeared in 
        (look at token_distribution_by_geohash). Must have 'token', 'global_count', and 'region_coverage' columns.
        geohas_precision (int, optional): must be between 1 (inclusive) and 12 (inclusive). 
        Larger precisions mean smaller partitioning of grids in [df]. The default param is 5.
        file_path (string, optional): path to a txt file storing the blacklist, where each line is a single token.
    """
    n_regions, token_df = token_distribution_by_geohash(gdf, geohash_precision)
    print(f"Total unique geohashes: {n_regions}")
    token_df['global_pct'] = token_df['global_count'] / token_df['global_count'].max()
    token_df['region_coverage'] = token_df['n_regions'] / n_regions
    blacklist = token_df[(token_df['global_pct'] > 0.01) & (token_df['region_coverage'] > 0.005)]['token'].to_list()
    if file_path:
        # Open the file in write mode ('w')
        with open(file_path, 'w') as f:  
            for item in blacklist:
                # Write each item followed by a newline
                f.write(f"{item}\n") 
    return blacklist

# %% [markdown]
# ### Example Usage

# %%
ne_df = pd.read_parquet("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/fsq_data/ne_fsq_pois_by_region.parquet")
ma_df = ne_df[(ne_df['latitude'].notna()) & (ne_df['longitude'].notna()) & (ne_df['region'] == "MA")]
ma_df['geometry'] = ma_df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
ma_gdf = gpd.GeoDataFrame(ma_df, geometry='geometry', crs="EPSG:4326")
ma_gdf['date_created'] = pd.to_datetime(ma_gdf['date_created'], errors='coerce')
ma_gdf['date_closed'] = pd.to_datetime(ma_gdf['date_closed'], errors='coerce')
print("ma len: " + str(len(ma_df)))

MIN_LAT = 42.2279
MAX_LAT = 42.4008
MIN_LON = -71.1912
MAX_LON = -70.9860

boston_df = ne_df[(ne_df['latitude'] >= MIN_LAT) & (ne_df['latitude'] <= MAX_LAT) & (ne_df['longitude'] >= MIN_LON) & (ma_df['longitude'] <= MAX_LON)]
print("bos len: " + str(len(boston_df)))

ri_df = ne_df[(ne_df['latitude'].notna()) & (ne_df['longitude'].notna()) & (ne_df['region'] == "RI")]
print("ri len: " + str(len(ri_df)))
# Out:
# /tmp/ipykernel_1571926/2535358565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ma_df['geometry'] = ma_df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
# ma len: 545701
# bos len: 112892
# ri len: 79723

# %%
ri_df['geometry'] = ri_df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)
ri_gdf = gpd.GeoDataFrame(ri_df, geometry='geometry', crs="EPSG:4326")
ri_gdf['date_created'] = pd.to_datetime(ri_gdf['date_created'], errors='coerce')
ri_gdf['date_closed'] = pd.to_datetime(ri_gdf['date_closed'], errors='coerce')
ri_gdf.to_parquet("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/fsq_data/ri_fsq_pois")
# Out:
# /tmp/ipykernel_1571926/678925919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ri_df['geometry'] = ri_df.apply(lambda row: Point(row['longitude'], row['latitude']), axis=1)

# %%
ri_blacklist = generate_blacklist(ri_df, geohash_precision = 7, file_name = '/share/garg/accessgaps2024/fsq_dedup_pipeline/ri_blklist_test')
ri_blacklist
# Out:
# Total POIs: 79723
# Total unique geohashes: 23359
# ['the',
#  'of',
#  'and',
#  'center',
#  'at',
#  'island',
#  'co',
#  'services',
#  'service',
#  'rhode',
#  'auto',
#  'school',
#  'providence',
#  'ri',
#  'voting',
#  'house',
#  'inc',
#  'newport',
#  'salon',
#  'office',
#  'group',
#  'home',
#  'east',
#  'restaurant',
#  'st',
#  'pizza',
#  'new',
#  'construction',
#  'church',
#  'park',
#  'financial',
#  'shop',
#  'dr',
#  'bank',
#  'associates',
#  'club',
#  'bar',
#  'company',
#  'care',
#  'law',
#  'cafe',
#  'room',
#  'hall',
#  'state',
#  'llc',
#  'street',
#  'studio',
#  'hill',
#  'repair',
#  'north',
#  'beach',
#  'farm',
#  'ocean',
#  'station',
#  'insurance',
#  'family',
#  'warwick',
#  'design',
#  'store',
#  'hair',
#  'market',
#  'england',
#  'union',
#  'south',
#  'electric',
#  'for',
#  'blue',
#  'fire',
#  'atm',
#  'on',
#  'sales',
#  'by',
#  'health',
#  'in',
#  'john',
#  'fitness',
#  'west',
#  'american',
#  'medical',
#  'bay',
#  'inn',
#  'america',
#  'management',
#  'community',
#  'field',
#  'building',
#  'solutions',
#  'grill',
#  'kitchen',
#  'car',
#  'united',
#  'bus',
#  'ave',
#  'town',
#  'body',
#  'spa',
#  'department',
#  'place',
#  'university',
#  'cleaning',
#  'therapy',
#  'side',
#  'stop',
#  'bitcoin',
#  'county',
#  'citizens',
#  'lounge',
#  'food',
#  'city',
#  'bakery',
#  'point',
#  'cranston',
#  'tree',
#  'realty',
#  'express',
#  'heating',
#  'plumbing',
#  'international',
#  'md',
#  'rhino',
#  'us',
#  'nails',
#  'to',
#  'pub',
#  'credit',
#  'coffee',
#  'landscaping',
#  'mobile',
#  'dunkin',
#  'deli',
#  'river',
#  'mortgage',
#  'all',
#  'la',
#  'gym',
#  'garden',
#  'world',
#  'systems',
#  'day',
#  'hope',
#  'barber',
#  'high',
#  'estate',
#  'little',
#  'dental',
#  'brown',
#  'memorial',
#  'painting',
#  'village',
#  'pond',
#  'hospital',
#  'green',
#  'nationwide',
#  'greenwich',
#  'truck',
#  'sports',
#  'bristol',
#  'arts',
#  'supply',
#  'block',
#  'art',
#  'road',
#  'valley',
#  'one',
#  'real',
#  'narragansett',
#  'cumberland',
#  'garage',
#  'liquors',
#  'library',
#  'gallery',
#  'storage',
#  'western',
#  'academy',
#  'elementary',
#  'pawtucket',
#  'party',
#  'mart',
#  'post',
#  'offices',
#  'public',
#  'works',
#  'ice',
#  'pool',
#  'sons',
#  'robert',
#  'dance',
#  'tax',
#  'pet',
#  'dog',
#  'central',
#  'physical',
#  'communications',
#  'beauty',
#  'oil',
#  'foods',
#  'grille',
#  'michael',
#  'general',
#  'photography',
#  'mexican',
#  'farms',
#  'agency',
#  'association',
#  'parking',
#  'pnc',
#  'chiropractic',
#  'water',
#  'cleaners',
#  'star',
#  'wireless',
#  'lot',
#  'wine',
#  'de',
#  'apartments',
#  'cox',
#  'lab',
#  'williams',
#  'security',
#  'red',
#  'national',
#  'glass',
#  'roofing',
#  'marine',
#  'del',
#  'david',
#  'tavern',
#  'corner',
#  'king',
#  'builders',
#  'pharmacy',
#  'rock',
#  'enterprises',
#  'automotive',
#  'paul',
#  'first',
#  'massage',
#  'music',
#  'property',
#  'cream',
#  'lawn',
#  'country',
#  'products',
#  'properties',
#  'palace',
#  'redbox',
#  'corporation']

# %%
# ne_df = pd.read_parquet("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/fsq_data/ne_fsq_pois_by_region.parquet")
# print("og len: " + str(len(ne_df)))
# # ne_regions = ['MA', 'ME', 'NH', 'CT', 'VT', 'RI']
# ne_regions = ['MA']
# ne_df = ne_df[(ne_df['latitude'].notna()) & (ne_df['longitude'].notna()) & (ne_df['region'].isin(ne_regions))]
n_regions, token_df = token_distribution_by_geohash(boston_df, geohash_precision=7)
token_df
# Out:
# Total POIs: 112892
#            token  global_count  n_regions
# 182       boston          6519       2372
# 103          the          5663       2802
# 312           of          3376       1921
# 251       center          2839       1574
# 1308          md          2668        183
# ...          ...           ...        ...
# 42897      asure             1          1
# 42886       tcaa             1          1
# 42885   celerity             1          1
# 42884  adfiliare             1          1
# 42883     innova             1          1
#
# [42908 rows x 3 columns]

# %%
token_df = pd.read_csv("/share/garg/accessgaps2024/fsq_dedup_pipeline/results/ma_blacklist_tokens")

# %%
token_df['global_pct'] = token_df['global_count'] / token_df['global_count'].max()
token_df['region_coverage'] = token_df['n_regions'] / n_regions
blacklist_tokens = token_df[(token_df['global_pct'] > 0.01) & (token_df['region_coverage'] > 0.005)]
# blacklist_tokens = blacklist_tokens.drop('Unnamed: 0', axis = 1)
blacklist_tokens
# Out:
#          token  global_count  n_regions  global_pct  region_coverage
# 182     boston          6519       2372    1.000000         0.219305
# 103        the          5663       2802    0.868692         0.259061
# 312         of          3376       1921    0.517871         0.177607
# 251     center          2839       1574    0.435496         0.145525
# 1308        md          2668        183    0.409265         0.016919
# ...        ...           ...        ...         ...              ...
# 1311       cpa            66         59    0.010124         0.005455
# 7698  language            66         61    0.010124         0.005640
# 2254   anthony            66         61    0.010124         0.005640
# 862      coach            66         59    0.010124         0.005455
# 465        men            66         59    0.010124         0.005455
#
# [634 rows x 5 columns]

# %%
for i, row in blacklist_tokens.iterrows():
    print(row['token'] + ", " + str(row['global_count']) + ", " + str(row['n_regions']))
# Out:
# boston, 6519, 2372
# the, 5663, 2802
# of, 3376, 1921
# center, 2839, 1574
# md, 2668, 183
# and, 2410, 1607
# st, 1890, 1240
# at, 1879, 1163
# street, 1822, 1236
# services, 1313, 916
# group, 1302, 811
# flight, 1269, 180
# office, 1243, 765
# co, 1223, 945
# park, 1191, 905
# school, 1182, 829
# bos, 1126, 170
# cafe, 1085, 773
# house, 1084, 846
# mbta, 1044, 738
# service, 1025, 862
# cambridge, 1023, 490
# bank, 935, 575
# inc, 932, 638
# bus, 891, 692
# square, 882, 543
# for, 869, 628
# room, 860, 546
# new, 853, 682
# associates, 834, 575
# to, 778, 409
# law, 777, 380
# salon, 775, 537
# market, 733, 565
# hall, 732, 424
# shop, 730, 579
# bar, 720, 508
# ave, 713, 503
# club, 712, 575
# restaurant, 710, 502
# harvard, 679, 288
# company, 673, 540
# auto, 669, 525
# health, 660, 481
# church, 652, 518
# studio, 651, 507
# financial, 631, 389
# care, 622, 491
# hill, 614, 425
# building, 614, 401
# station, 613, 503
# united, 602, 332
# design, 588, 469
# management, 574, 408
# stop, 573, 479
# pizza, 569, 456
# university, 556, 250
# hair, 556, 418
# home, 553, 456
# city, 551, 450
# college, 532, 271
# mit, 526, 109
# voting, 518, 346
# south, 516, 352
# realty, 515, 397
# on, 513, 437
# american, 507, 368
# medical, 498, 252
# by, 494, 441
# quincy, 486, 271
# store, 483, 404
# in, 479, 415
# union, 478, 369
# dr, 478, 314
# america, 477, 390
# lounge, 476, 375
# community, 476, 416
# bay, 471, 282
# food, 471, 375
# atm, 465, 381
# east, 465, 333
# brookline, 455, 212
# plumbing, 450, 404
# llc, 450, 335
# dental, 449, 331
# insurance, 445, 330
# john, 439, 354
# international, 439, 347
# construction, 437, 399
# hospital, 435, 140
# delta, 428, 112
# place, 423, 321
# massachusetts, 420, 290
# england, 409, 343
# party, 406, 341
# estate, 398, 298
# repair, 398, 346
# real, 398, 296
# beacon, 395, 214
# library, 391, 265
# mass, 391, 305
# spa, 387, 313
# parking, 384, 314
# conference, 379, 221
# kitchen, 374, 329
# garage, 369, 325
# day, 366, 329
# fitness, 366, 311
# north, 358, 252
# us, 351, 190
# family, 348, 311
# green, 346, 290
# children, 343, 123
# car, 343, 276
# garden, 339, 279
# hq, 337, 257
# state, 334, 212
# lab, 332, 242
# somerville, 331, 188
# express, 328, 277
# west, 326, 231
# grill, 325, 285
# coffee, 320, 264
# truck, 318, 234
# zipcar, 316, 292
# public, 313, 254
# airlines, 304, 81
# ma, 304, 275
# gym, 302, 267
# institute, 302, 248
# partners, 297, 200
# department, 296, 210
# one, 296, 237
# cleaning, 295, 272
# apartments, 293, 254
# solutions, 293, 242
# electric, 291, 279
# world, 288, 241
# art, 284, 227
# field, 282, 246
# commonwealth, 279, 190
# capital, 278, 162
# la, 276, 232
# beauty, 274, 232
# com, 273, 235
# cleaners, 272, 245
# media, 270, 224
# charles, 269, 207
# agency, 266, 232
# program, 265, 125
# bakery, 265, 230
# arts, 265, 220
# train, 264, 152
# bitcoin, 264, 224
# music, 261, 205
# academy, 261, 225
# blue, 257, 221
# dunkin, 255, 241
# therapy, 255, 208
# body, 255, 223
# back, 253, 162
# floor, 252, 204
# offices, 252, 186
# memorial, 248, 217
# heating, 245, 231
# gallery, 245, 176
# road, 244, 206
# research, 239, 194
# sports, 238, 203
# association, 238, 209
# gate, 238, 102
# village, 237, 161
# nails, 237, 194
# general, 234, 189
# booth, 234, 66
# life, 234, 212
# festival, 233, 175
# consulting, 232, 202
# mobile, 228, 210
# central, 228, 178
# michael, 227, 163
# first, 226, 205
# court, 224, 179
# credit, 223, 191
# robert, 223, 173
# corner, 221, 169
# dedham, 219, 113
# washington, 219, 163
# route, 219, 198
# travel, 216, 194
# studios, 216, 184
# pc, 214, 150
# end, 212, 137
# trust, 211, 195
# hotel, 211, 151
# fenway, 210, 84
# line, 207, 166
# james, 207, 167
# palace, 205, 192
# wine, 202, 175
# massage, 202, 152
# corporation, 202, 168
# laundry, 201, 180
# commuter, 199, 109
# david, 199, 146
# paul, 198, 162
# roxbury, 198, 140
# brighton, 198, 115
# river, 197, 175
# photography, 197, 168
# pnc, 196, 191
# fire, 195, 158
# avenue, 193, 175
# playground, 192, 185
# red, 191, 163
# dog, 191, 181
# systems, 190, 168
# barber, 190, 166
# federal, 190, 154
# bu, 188, 82
# de, 187, 175
# marketing, 187, 153
# belmont, 186, 96
# education, 185, 166
# rail, 184, 104
# high, 184, 149
# yoga, 184, 156
# tax, 183, 159
# pool, 182, 165
# painting, 182, 174
# national, 182, 150
# pharmacy, 180, 161
# star, 179, 157
# taxi, 179, 146
# properties, 179, 159
# shuttle, 179, 152
# little, 178, 165
# headquarters, 178, 164
# development, 175, 159
# starbucks, 175, 160
# point, 174, 132
# sweet, 174, 161
# all, 174, 163
# air, 173, 112
# watertown, 171, 101
# lot, 171, 162
# pub, 169, 150
# foundation, 169, 150
# science, 169, 132
# dance, 169, 146
# supply, 168, 160
# clinic, 168, 130
# best, 167, 153
# business, 167, 146
# charging, 167, 157
# citizens, 166, 108
# student, 165, 118
# dorchester, 164, 127
# post, 164, 139
# foods, 164, 155
# western, 163, 156
# milton, 163, 106
# mortgage, 162, 99
# joseph, 162, 136
# big, 162, 146
# tree, 162, 148
# architects, 161, 134
# training, 161, 151
# housing, 161, 141
# communications, 159, 146
# technology, 159, 144
# plaza, 158, 115
# global, 157, 140
# king, 157, 139
# attorney, 157, 106
# rd, 156, 137
# allston, 155, 83
# women, 153, 111
# glass, 153, 135
# laboratory, 152, 70
# adams, 152, 115
# harbor, 152, 111
# security, 151, 136
# wellness, 151, 128
# chestnut, 151, 99
# up, 150, 135
# medicine, 150, 104
# usa, 149, 131
# works, 149, 136
# liquors, 149, 136
# el, 148, 132
# chelsea, 147, 87
# energy, 146, 129
# roof, 146, 136
# campus, 146, 116
# bridge, 145, 138
# physical, 144, 129
# learning, 144, 137
# ice, 144, 131
# airport, 144, 111
# beer, 143, 105
# project, 143, 130
# museum, 143, 103
# productions, 141, 129
# inn, 141, 115
# mexican, 140, 131
# seaport, 140, 59
# boutique, 140, 115
# william, 139, 123
# door, 139, 132
# newton, 139, 95
# suffolk, 138, 68
# property, 138, 129
# santander, 137, 130
# metro, 137, 124
# black, 136, 128
# theatre, 135, 95
# fine, 134, 111
# deli, 134, 117
# charlestown, 134, 86
# walk, 133, 109
# advisors, 133, 96
# moving, 132, 123
# common, 132, 90
# logan, 132, 99
# cab, 131, 118
# social, 131, 115
# eye, 131, 110
# spot, 131, 128
# tavern, 131, 111
# nail, 131, 119
# good, 131, 121
# thai, 131, 110
# block, 130, 109
# storage, 130, 108
# society, 130, 122
# thomas, 130, 112
# deck, 130, 120
# it, 129, 123
# town, 129, 117
# barbershop, 129, 119
# broadway, 128, 91
# lee, 127, 98
# marathon, 127, 89
# sushi, 126, 107
# technologies, 125, 108
# hubway, 125, 122
# rock, 125, 115
# meeting, 125, 94
# night, 124, 111
# transportation, 123, 106
# old, 122, 108
# peter, 122, 103
# dry, 121, 113
# edward, 121, 86
# summer, 121, 97
# saint, 120, 104
# llp, 120, 78
# den, 119, 113
# sales, 119, 113
# parcel, 119, 118
# mary, 119, 90
# manor, 118, 105
# box, 118, 94
# network, 117, 107
# pizzeria, 117, 108
# libertyx, 117, 116
# navy, 116, 107
# my, 116, 111
# elizabeth, 116, 61
# with, 115, 110
# white, 115, 106
# rental, 115, 104
# urban, 115, 108
# mark, 114, 90
# cuisine, 114, 98
# computer, 113, 107
# skin, 113, 92
# brothers, 113, 107
# convenience, 113, 108
# smith, 113, 98
# drive, 112, 89
# ii, 112, 107
# roofing, 112, 107
# seafood, 111, 90
# tour, 110, 91
# comcast, 110, 98
# paint, 110, 104
# fresh, 110, 99
# tech, 109, 99
# eastern, 109, 98
# tea, 108, 92
# franklin, 108, 86
# acupuncture, 108, 85
# chase, 108, 80
# fish, 108, 92
# press, 107, 102
# tours, 107, 99
# boylston, 107, 63
# greater, 106, 100
# sons, 106, 101
# district, 106, 92
# shore, 105, 93
# neighborhood, 105, 99
# engineering, 105, 84
# chiropractic, 105, 96
# richard, 105, 90
# surgery, 105, 69
# parade, 105, 91
# sea, 104, 90
# alliance, 104, 93
# wireless, 103, 86
# davis, 103, 64
# top, 103, 102
# circle, 103, 83
# stone, 103, 94
# sq, 103, 91
# bbq, 103, 93
# factory, 103, 95
# contracting, 103, 100
# sewer, 103, 102
# child, 102, 90
# bistro, 102, 99
# chinese, 101, 83
# main, 101, 88
# elementary, 101, 89
# citibank, 101, 101
# cvs, 101, 92
# chicken, 101, 88
# liberty, 101, 65
# space, 100, 94
# super, 100, 95
# catering, 99, 91
# dmd, 99, 61
# italian, 99, 94
# plus, 99, 95
# gas, 98, 90
# class, 98, 82
# legal, 98, 77
# water, 98, 92
# martin, 97, 83
# beach, 97, 88
# cream, 97, 90
# local, 97, 87
# tower, 96, 83
# stand, 96, 85
# jewelry, 96, 68
# custom, 96, 91
# drain, 96, 95
# time, 95, 89
# way, 95, 85
# limo, 95, 88
# annual, 95, 62
# gourmet, 95, 83
# longwood, 95, 62
# wealth, 94, 59
# taqueria, 94, 84
# summit, 94, 68
# your, 94, 89
# love, 94, 90
# eleven, 93, 90
# atlantic, 93, 78
# masonry, 93, 86
# theater, 93, 76
# godiva, 93, 91
# healthcare, 92, 83
# hyde, 92, 66
# run, 92, 77
# mt, 92, 78
# police, 92, 70
# mart, 92, 91
# bon, 92, 81
# creative, 92, 88
# williams, 92, 73
# george, 91, 79
# news, 91, 80
# yard, 91, 86
# digital, 91, 82
# pond, 91, 79
# laundromat, 91, 86
# tremont, 90, 56
# fund, 90, 76
# landscaping, 90, 88
# balance, 90, 88
# centre, 90, 75
# mr, 90, 86
# baptist, 90, 83
# funeral, 90, 80
# terrace, 89, 73
# four, 89, 80
# jr, 89, 75
# stephen, 89, 69
# holiday, 89, 75
# kennedy, 88, 71
# brown, 88, 74
# professional, 88, 82
# row, 88, 60
# hot, 88, 77
# pharmaceuticals, 88, 65
# go, 87, 77
# video, 87, 85
# hancock, 87, 61
# td, 87, 60
# pet, 86, 83
# exchange, 86, 72
# furniture, 86, 76
# area, 86, 80
# worldwide, 86, 74
# temple, 86, 73
# council, 85, 77
# rent, 85, 77
# emergency, 85, 78
# great, 85, 78
# sullivan, 84, 77
# warren, 84, 64
# andrew, 84, 63
# jp, 84, 60
# farm, 84, 72
# pain, 83, 71
# private, 83, 69
# branch, 83, 70
# condo, 83, 83
# beth, 83, 55
# tennis, 83, 79
# island, 82, 78
# enterprise, 82, 77
# appliance, 82, 79
# enterprises, 81, 78
# entertainment, 81, 79
# jamaica, 81, 64
# software, 81, 70
# ventures, 81, 72
# xfinity, 81, 79
# hub, 81, 73
# team, 81, 73
# benjamin, 80, 68
# assoc, 80, 76
# daniel, 80, 67
# oil, 80, 72
# pro, 79, 70
# boat, 79, 71
# burger, 79, 75
# resources, 79, 73
# labs, 79, 72
# le, 79, 71
# zone, 79, 74
# locksmith, 79, 74
# youth, 78, 70
# mount, 78, 62
# mike, 78, 72
# hills, 78, 63
# grille, 78, 74
# fort, 77, 60
# wash, 77, 67
# living, 77, 74
# wide, 77, 76
# fest, 77, 63
# innovation, 77, 74
# winter, 77, 61
# advanced, 76, 73
# do, 76, 58
# kelly, 76, 72
# condominium, 76, 73
# dining, 75, 70
# senior, 75, 62
# breakfast, 75, 72
# taste, 75, 66
# out, 74, 72
# casa, 74, 68
# rehab, 74, 70
# radio, 74, 66
# christian, 74, 69
# bike, 74, 71
# open, 74, 66
# residence, 74, 57
# data, 73, 63
# suite, 73, 62
# shoe, 73, 67
# fedex, 73, 71
# resource, 73, 67
# frank, 73, 66
# window, 73, 65
# show, 72, 58
# charter, 72, 65
# murphy, 72, 62
# is, 72, 69
# movers, 72, 68
# carpet, 72, 72
# residential, 72, 67
# jack, 71, 63
# healing, 71, 63
# happy, 71, 68
# study, 71, 61
# corporate, 71, 69
# comm, 71, 58
# designs, 71, 68
# shack, 70, 67
# century, 70, 63
# dollar, 70, 60
# granite, 70, 57
# lisa, 70, 56
# scott, 70, 63
# restoration, 70, 67
# courts, 70, 69
# control, 70, 69
# max, 69, 57
# automotive, 69, 63
# land, 69, 68
# firm, 68, 59
# pop, 68, 56
# middle, 68, 55
# northeast, 68, 58
# loft, 68, 66
# flower, 68, 66
# brewing, 67, 64
# shops, 67, 65
# me, 67, 64
# spring, 67, 64
# condominiums, 67, 66
# landscape, 67, 63
# laser, 67, 57
# auditorium, 67, 60
# liquor, 67, 63
# gardens, 67, 62
# subway, 67, 66
# savings, 67, 61
# smoke, 67, 64
# modern, 66, 61
# rose, 66, 57
# cpa, 66, 59
# language, 66, 61
# anthony, 66, 61
# coach, 66, 59
# men, 66, 59

# %%
ne_global_blacklist = ne_global_rows['token'].to_list
file_name = "output.txt"
with open("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/ne_blacklist.txt", 'w') as f:  # Open the file in write mode ('w')
    for item in ne_global_blacklist:
        f.write(f"{item}\n")  # Write each item followed by a newline
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ne_global_blacklist = ne_global_rows['token'].to_list
#       2 file_name = "output.txt"
#       3 with open("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/ne_blacklist.txt", 'w') as f:  # Open the file in write mode ('w')
#
# Cell In[9], line 1
# ----> 1 ne_global_blacklist = ne_global_rows['token'].to_list
#       2 file_name = "output.txt"
#       3 with open("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/ne_blacklist.txt", 'w') as f:  # Open the file in write mode ('w')
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1112, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1090, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File /share/garg/conda_virtualenvs/wildfires/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File /share/garg/conda_virtualenvs/wildfires/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File /share/garg/conda_virtualenvs/wildfires/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File /share/garg/conda_virtualenvs/wildfires/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
man_pois = pd.read_parquet("/share/garg/accessgaps2024/fsq_dedup_pipeline/data/fsq_data/man_fsq_pois")
blacklist = generate_blacklist(man_pois, geohash_precision = 7, file_path = "/share/garg/accessgaps2024/fsq_dedup_pipeline/data/blacklists/manhattan_blacklist")
blacklist
# Out:
# Total POIs: 396948
# Total unique geohashes: 8190
# ['the',
#  'nyc',
#  'taxi',
#  'new',
#  'of',
#  'md',
#  'street',
#  'york',
#  'and',
#  'st',
#  'center',
#  'at',
#  'park',
#  'group',
#  'inc',
#  'office',
#  'dr',
#  'west',
#  'studio',
#  'ave',
#  'ny',
#  'east',
#  'bus',
#  'bar',
#  'cafe',
#  'co',
#  'hq',
#  'restaurant',
#  'shop',
#  'city',
#  'avenue',
#  'services',
#  'for',
#  'room',
#  'salon',
#  'deli',
#  'manhattan',
#  'house',
#  'mta',
#  'in',
#  'food',
#  'club',
#  'school',
#  'on',
#  'party',
#  'to',
#  'spa',
#  'gallery',
#  'by',
#  'service',
#  'associates',
#  'pizza',
#  'lounge',
#  'media',
#  'design',
#  'law',
#  'llc',
#  'management',
#  'broadway',
#  'bank',
#  'coffee',
#  'cab',
#  'international',
#  'la',
#  'market',
#  'store',
#  'art',
#  'health',
#  'parking',
#  'day',
#  'studios',
#  'up',
#  'company',
#  'central',
#  'world',
#  'care',
#  'station',
#  'square',
#  'hair',
#  'capital',
#  'kitchen',
#  'gym',
#  'american',
#  'cleaners',
#  'hotel',
#  'brooklyn',
#  'medical',
#  'financial',
#  'church',
#  'beauty',
#  'usa',
#  'cart',
#  'america',
#  'repair',
#  'com',
#  'grill',
#  'express',
#  'fitness',
#  'dental',
#  'de',
#  'grocery',
#  'truck',
#  'building',
#  'home',
#  'pop',
#  'one',
#  'green',
#  'hudson',
#  'car',
#  'north',
#  'place',
#  'hall',
#  'garden',
#  'harlem',
#  'john',
#  'realty',
#  'plaza',
#  'village',
#  'voting',
#  'stop',
#  'floor',
#  'partners',
#  'nyu',
#  'pc',
#  'music',
#  'festival',
#  'wine',
#  'union',
#  'united',
#  'conference',
#  'global',
#  'arts',
#  'madison',
#  'therapy',
#  'grand',
#  'bakery',
#  'david',
#  'construction',
#  'solutions',
#  'side',
#  'rooftop',
#  'lab',
#  'offices',
#  'nail',
#  'el',
#  'digital',
#  'corporation',
#  'bike',
#  'college',
#  'nails',
#  'sushi',
#  'institute',
#  'auto',
#  'fashion',
#  'corp',
#  'jewelry',
#  'foundation',
#  'agency',
#  'michael',
#  'big',
#  'show',
#  'real',
#  'productions',
#  'morgan',
#  'network',
#  'pharmacy',
#  'dds',
#  'social',
#  'community',
#  'chelsea',
#  'showroom',
#  'marketing',
#  'robert',
#  'business',
#  'lee',
#  'mobile',
#  'consulting',
#  'blue',
#  'halal',
#  'soho',
#  'stanley',
#  'sports',
#  'public',
#  'red',
#  'south',
#  'dog',
#  'booth',
#  'barber',
#  'gourmet',
#  'headquarters',
#  'cleaning',
#  'estate',
#  'photography',
#  'midtown',
#  'national',
#  'garage',
#  'family',
#  'citi',
#  'star',
#  'university',
#  'little',
#  'best',
#  'fair',
#  'project',
#  'academy',
#  'theatre',
#  'laundry',
#  'life',
#  'physical',
#  'all',
#  'electric',
#  'island',
#  'phd',
#  'space',
#  'river',
#  'dance',
#  'us',
#  'hill',
#  'first',
#  'my',
#  'le',
#  'fine',
#  'systems',
#  'chicken',
#  'library',
#  'travel',
#  'line',
#  'stand',
#  'subway',
#  'times',
#  'laundromat',
#  'washington',
#  'wellness',
#  'with',
#  'event',
#  'juice',
#  'time',
#  'palace',
#  'king',
#  'metro',
#  'plumbing',
#  'columbia',
#  'yoga',
#  'creative',
#  'entertainment',
#  'communications',
#  'training',
#  'court',
#  'llp',
#  'theater',
#  'body',
#  'insurance',
#  'chinese',
#  'black',
#  'exchange',
#  'high',
#  'general',
#  'boutique',
#  'roof',
#  'go',
#  'state',
#  'tea',
#  'spot',
#  'it',
#  'holiday',
#  'empire',
#  'wall',
#  'association',
#  'ice',
#  'department',
#  'shoe',
#  'thai',
#  'night',
#  'james',
#  'acupuncture',
#  'yellow',
#  'good',
#  'tower',
#  'end',
#  'town',
#  'hot',
#  'tribeca',
#  'news',
#  'lexington',
#  'trading',
#  'fresh',
#  'urban',
#  'atm',
#  'apple',
#  'playground',
#  'riverside',
#  'corner',
#  'ps',
#  'tech',
#  'run',
#  'tour',
#  'sweet',
#  'summit',
#  'train',
#  'society',
#  'tax',
#  'parade',
#  'development',
#  'bridge',
#  'upper',
#  'peter',
#  'fruit',
#  'surgery',
#  'security',
#  'bbq',
#  'medicine',
#  'njt',
#  'av',
#  'starbucks',
#  'williamsburg',
#  'tree',
#  'magazine',
#  'water',
#  'cup',
#  'factory',
#  'burger',
#  'fort',
#  'supply',
#  'hospital',
#  'astoria',
#  'fifth',
#  'pizzeria',
#  'white',
#  'research',
#  'terrace',
#  'downtown',
#  'technology',
#  'firm',
#  'heating',
#  'loft',
#  'week',
#  'love',
#  'photo',
#  'charging',
#  'spring',
#  'ii',
#  'happy',
#  'paul',
#  'museum',
#  'mr',
#  'apartments',
#  'mark',
#  'post',
#  'taco',
#  'gate',
#  'sale',
#  'local',
#  'film',
#  'joseph',
#  'work',
#  'diamond',
#  'corporate',
#  'advisors',
#  'plus',
#  'top',
#  'nj',
#  'chase',
#  'columbus',
#  'cream',
#  'pool',
#  'van',
#  'architects',
#  'william',
#  'barbershop',
#  'do',
#  'mount',
#  'casa',
#  'women',
#  'team',
#  'summer',
#  'great',
#  'wireless',
#  'field',
#  'locksmith',
#  'long',
#  'massage',
#  'george',
#  'walk',
#  'inn',
#  'clinic',
#  'super',
#  'bistro',
#  'box',
#  'mexican',
#  'foods',
#  'tours',
#  'cuisine',
#  'pier',
#  'no',
#  'dry',
#  'district',
#  'memorial',
#  'kids',
#  'enterprises',
#  'carpet',
#  'sinai',
#  'out',
#  'gold',
#  'man',
#  'moving',
#  'custom',
#  'dunkin',
#  'hardware',
#  'lincoln',
#  'marathon',
#  'education',
#  'farm',
#  'towers',
#  'beer',
#  'sales',
#  'press',
#  'amsterdam',
#  'skin',
#  'properties',
#  'designs',
#  'metropolitan',
#  'hoboken',
#  'credit',
#  'awards',
#  'jay',
#  'storage',
#  'furniture',
#  'technologies',
#  'joe',
#  'royal',
#  'your',
#  'annual',
#  'gotham',
#  'golden',
#  'suite',
#  'richard',
#  'live',
#  'queens',
#  'block',
#  'video',
#  'charles',
#  'children',
#  'dermatology',
#  'two',
#  'rock',
#  'christmas',
#  'attorney',
#  'me',
#  'pnc',
#  'meat',
#  'ms',
#  'fish',
#  'pllc',
#  'housing',
#  'works',
#  'point',
#  'sample',
#  'mission',
#  'class',
#  'hunter',
#  'liberty',
#  'drive',
#  'laser',
#  'birthday',
#  'thomas',
#  'eye',
#  'labs',
#  'heights',
#  'chiropractic',
#  'air',
#  'computer',
#  'men',
#  'lic',
#  'apartment',
#  'young',
#  'famous',
#  'halloween',
#  'five',
#  'zipcar',
#  'stone',
#  'pet',
#  'verizon',
#  'diner',
#  'kim',
#  'rose',
#  'asian',
#  'daniel',
#  'lane',
#  'is',
#  'breakfast',
#  'learning',
#  'sun',
#  'printing',
#  'steven',
#  'brothers',
#  'amtrak',
#  'catering',
#  'glass',
#  'pilates',
#  'greenwich',
#  'andrew',
#  'events',
#  'expo',
#  'fund',
#  'mini',
#  'greenpoint',
#  'liquor',
#  'professional',
#  'zone',
#  'tattoo',
#  'natural',
#  'pain',
#  'brown',
#  'council',
#  'foot',
#  'limo',
#  'enterprise',
#  'fire',
#  'modern',
#  'launch',
#  'smith',
#  'flowers',
#  'wealth',
#  'books',
#  'blvd',
#  'vintage',
#  'bagel',
#  'uptown',
#  'mortgage',
#  'restoration',
#  'ltd',
#  'collection',
#  'china',
#  'del',
#  'italian',
#  'candy',
#  'tv',
#  'you',
#  'mart',
#  'wedding',
#  'cpa',
#  'private',
#  'meeting',
#  'living',
#  'japanese',
#  'smoke',
#  'spirits',
#  'radio',
#  'off',
#  'organic',
#  'gramercy',
#  'hell',
#  'style',
#  'wines',
#  'open',
#  'industries',
#  'collective',
#  'worldwide',
#  'track',
#  'property',
#  'dentistry',
#  'films',
#  'alliance',
#  'experience',
#  'architecture',
#  'records',
#  'book',
#  'bronx',
#  'circle',
#  'data',
#  'federal',
#  'nicholas',
#  'pro',
#  'luxury',
#  'old',
#  'sky',
#  'jersey',
#  'free',
#  'pub',
#  'secret',
#  'ventures',
#  'cornell',
#  'silver',
#  'duane',
#  'stage',
#  'table',
#  'bowery',
#  'camp',
#  'cohen',
#  'pr',
#  'tavern',
#  'mary',
#  'elizabeth',
#  'nations',
#  'gift',
#  'taste',
#  'henry',
#  'bergen',
#  'advanced',
#  'from',
#  'alexander',
#  'lucky',
#  'warehouse',
#  'frank',
#  'icon',
#  'energy',
#  'wide',
#  'reade',
#  'anthony',
#  'jack',
#  'vision',
#  'lady',
#  'third',
#  'program',
#  'martin',
#  'production',
#  'liquors',
#  'dentist',
#  'rug',
#  'hope',
#  'residence',
#  'shoes',
#  'ramen',
#  'bryant',
#  'rental',
#  'deck',
#  'den',
#  'murray',
#  'shuttle',
#  'unisex',
#  'print',
#  'sons',
#  'grace',
#  'way',
#  'here',
#  'board',
#  'road',
#  'maria',
#  'senior',
#  'science',
#  'trade',
#  'light',
#  'elite',
#  'jeffrey',
#  'advertising',
#  'door',
#  'lenox',
#  'doctor',
#  'da',
#  'scott',
#  'power',
#  'nyrr',
#  'noodle',
#  'land',
#  'french',
#  'beach',
#  'forum',
#  'stephen',
#  'apparel',
#  'lighting',
#  'parcel',
#  'magic']

# %%
GLOBAL_FOOD = {"pizza", "pizzeria", "cafe", "caffe", "coffee", "grill", "restaurant", "bar", "deli", "bakery", "express",
                  "market", "shop", "mart", "store", "grocery", "supermarket", "food", "gourmet", "cart", "fresh", "kitchen", 
                  "diner", "pub", "bistro", "tavern", "farm", "chicken", "burger", "sandwich", "taco", "tacos", "sushi", "noodle", "noodles"
                  "salad", "sub", "ice cream", "dessert", "breakfast", "brunch", "lunch", "dinner", "takeout", "delivery", 
                  "snack", "chocolate", "tea", "juice", "smoothie", "wine", "beer", "cocktail", "brewery", "distillery", 
                  "winery", "patisserie", "pastry", "bagel", "donut", "pancake", "waffle", "crepe", "treat", "cuisine", "truck",
                  "italian", "mexican", "chinese", "japanese", "korean", "indian", "thai", "vietnamese", "greek", "spanish",
                  "french", "american", "cuban", "cajun", "creole", "soul food", "bbq", "steakhouse", "seafood",
                  "vegetarian", "vegan", "gluten-free", "organic", "local", "artisan", "handmade", "craft", "homemade",
                  "family-owned", "authentic", "traditional", "fusion", "gastro", "gastropub", "halal", "kosher"}
GLOBAL_TRANS_ADDR = {"east", "west", "north", "south", "st", "street", "ave", "avenue", 
                 "blvd", "road", "rd", "rd.", "drive", "cab", "car", "truck", "van", "taxi", "metro", "sub", "subway", "mta", "station", "apt", "apartment", "station", "corner", "bus", "express", "line", "line", "plaza", "plz", "square", "sq", "lane", "ln", "way", "wy", "court", "ct",
                 "park", "pl", "pkwy", "parkway", "circle", "cir", "highway", "hwy", "route", "rte", "exit", "exit", "bridge", "bridges", "crossing", "crossings",
                 "crossings", "intersection", "intersections", "boulevard", "boulevards", "roadway", "roadways", "driveway", "driveways","avenue", "avenues", "streetway"}
GLOBAL_LOC = {"city", "village", "town", "museum", "group", "house", "center", "ctr", "art", "shop", "show", "theatre", "theater", "office", "service", "services", "bank", "jewelry", "club", 
              "community", "garden", "park", "field", "beach", "ocean", "river", "playground", "school", "college", "university", "library", "gallery", "studio", "hall", "auditorium", "venue", "church"
              "cleaner", "cleaners", "laundry", "laundromt", "pharmacy", "church", "clinic", "gym", "hospital", "fitness", "nail", "nails", "salon", "spa", "barber", "project", "projects"}
GLOBAL_WORDS = {"the", "a", "an", "and", "&", "of", "in", "for", "to", "at", "@", "on", "out", "with", "by", "from", "as", "that", "this", "it", "is", "was", "be", "are", "day", "care", "co."}
GLOBAL_SCHOOL_WRDS = {"high", "middle", "elementary", "school", "academy", "charter", "magnet", "daycare", "day", "care"}
GLOBAL_FIRE_STATION = {"fdny", "engine", "ems", "rescue", "group"}
GLOBAL_POLICE_STATION = {"nypd"}
LOCAL_PHRASES_NYC = {"new", "york", "nyc", "manhattan", "brooklyn", "queens", "bronx", "staten", "island", "ny", "city", "upper", "lower", "side", "marks"}
COMMON_PHRASES = GLOBAL_FOOD.union(GLOBAL_TRANS_ADDR).union(GLOBAL_LOC).union(GLOBAL_WORDS).union(LOCAL_PHRASES_NYC).union(GLOBAL_SCHOOL_WRDS).union(GLOBAL_FIRE_STATION).union(GLOBAL_POLICE_STATION)

# Neighborhood and local area terms to ignore during name normalization
LOCAL_AREAS_NYC = [

    # Lower Manhattan / East Side
    "alphabet", "lower", "west", "north", "east", "south", "street", "side", "les",
    "two", "bridges", "chinatown", "nolita", "soho", "noho", "little", "italy",
    "bowery", "seaport", "civic", "center", "marks", "wall", "financial", "tribeca", "fidi", "delancey",
    "clinton", "canal",
    
    # Midtown / Gramercy / Chelsea
    "gramercy", "flatiron", "murray", "midtown",
    "koreatown", "garment", "district", "nomad", "chelsea", "hell", "hells",
    "hudson", "yards", "theater", "times", "square", "rockefeller", "kips", "turtle", "bay", "herald", "penn", "station", "empire",
    
    # Upper Manhattan
    "upper", "harlem", "spanish", "heights",
    "morningside", "hamilton", "inwood", "washington","manhattenville", "sugar", "hill", "dyckman", "fort", "george", "columbia",
    
    # Downtown / River Areas / Parks
    "tompkins", "river", "park",
    "stuytown", "stuyvesant", "oval", "union",
    "madison", "bryant", "central", "battery", "riverside", "fdr", "drive",
    
    # Outer Boroughs or Bordering Areas
    "brooklyn", "queens", "bushwick", "greenpoint", "williamsburg", "bed-stuy",
    "dumbo", "long island city", "astoria", "ridgewood",
]

NYC_BLACKLIST = COMMON_PHRASES.union(LOCAL_AREAS_NYC)

print(set(blacklist) - set(LOCAL_AREAS_NYC))
print(set(LOCAL_AREAS_NYC).intersection(set(blacklist)))
# print(set(blacklist) - set(NYC_BLACKLIST))
# Out:
# {'pain', 'state', 'digital', 'cuisine', 'tavern', 'american', 'party', 'gallery', 'spot', 'network', 'starbucks', 'academy', 'college', 'clinic', 'voting', 'fund', 'casa', 'cornell', 'nj', 'architects', 'dental', 'of', 'diamond', 'downtown', 'nicholas', 'off', 'tree', 'pizza', 'gym', 'brown', 'cpa', 'international', 'repair', 'art', 'joseph', 'group', 'great', 'metro', 'studio', 'tech', 'house', 'laundry', 'ny', 'manhattan', 'space', 'partners', 'unisex', 'hotel', 'village', 'anthony', 'library', 'headquarters', 'limo', 'technology', 'production', 'one', 'nyc', 'ii', 'technologies', 'richard', 'roof', 'professional', 'stanley', 'liquors', 'conference', 'lincoln', 'sports', 'david', 'laundromat', 'news', 'candy', 'ps', 'dance', 'association', 'inc', 'program', 'phd', 'wine', 'lounge', 'cohen', 'third', 'beach', 'in', 'citi', 'pnc', 'french', 'magazine', 'construction', 'lexington', 'training', 'nations', 'water', 'museum', 'mortgage', 'farm', 'records', 'parade', 'amsterdam', 'john', 'stop', 'class', 'marketing', 'entertainment', 'at', 'blvd', 'christmas', 'shop', 'bridge', 'cream', 'annual', 'taste', 'martin', 'your', 'rooftop', 'university', 'md', 'tv', 'van', 'verizon', 'door', 'apartment', 'exchange', 'long', 'road', 'school', 'apparel', 'kids', 'spirits', 'golden', 'summer', 'thai', 'walk', 'enterprises', 'office', 'wines', 'beauty', 'nyu', 'mexican', 'acupuncture', 'mobile', 'loft', 'de', 'llp', 'pub', 'plus', 'magic', 'the', 'foods', 'apartments', 'housing', 'gourmet', 'realty', 'festival', 'global', 'barbershop', 'old', 'blue', 'productions', 'private', 'corp', 'halal', 'development', 'local', 'fine', 'insurance', 'air', 'energy', 'pilates', 'free', 'luxury', 'mount', 'education', 'alliance', 'happy', 'week', 'black', 'properties', 'bank', 'lee', 'urban', 'land', 'forum', 'metropolitan', 'liquor', 'star', 'heating', 'pharmacy', 'plaza', 'rock', 'studios', 'ave', 'tattoo', 'hot', 'rug', 'shoe', 'laser', 'deck', 'national', 'restaurant', 'mark', 'salon', 'wedding', 'king', 'stephen', 'sweet', 'massage', 'parking', 'coffee', 'skin', 'fruit', 'furniture', 'gotham', 'restoration', 'fresh', 'way', 'green', 'creative', 'paul', 'lane', 'field', 'glass', 'bakery', 'yoga', 'for', 'sushi', 'research', 'bagel', 'grill', 'spa', 'collective', 'hardware', 'breakfast', 'is', 'cleaners', 'room', 'memorial', 'credit', 'china', 'lucky', 'suite', 'robert', 'new', 'tours', 'fish', 'advertising', 'york', 'sales', 'subway', 'event', 'store', 'vision', 'charging', 'plumbing', 'eye', 'sale', 'daniel', 'hoboken', 'board', 'dog', 'best', 'diner', 'firm', 'body', 'andrew', 'grand', 'carpet', 'night', 'open', 'doctor', 'corner', 'le', 'white', 'hq', 'health', 'trading', 'el', 'foot', 'women', 'data', 'bergen', 'tour', 'advisors', 'joe', 'liberty', 'noodle', 'me', 'work', 'beer', 'america', 'go', 'day', 'asian', 'arts', 'bbq', 'wellness', 'jeffrey', 'fair', 'apple', 'pc', 'brothers', 'medical', 'auto', 'labs', 'services', 'market', 'capital', 'dermatology', 'bronx', 'industries', 'live', 'storage', 'pr', 'truck', 'films', 'tower', 'society', 'italian', 'computer', 'worldwide', 'theatre', 'silver', 'real', 'table', 'nails', 'moving', 'booth', 'cup', 'marathon', 'steven', 'organic', 'circle', 'team', 'catering', 'holiday', 'residence', 'cart', 'mary', 'parcel', 'bus', 'nyrr', 'gate', 'camp', 'federal', 'co', 'mta', 'st', 'do', 'broadway', 'frank', 'family', 'here', 'warehouse', 'taxi', 'box', 'james', 'burger', 'hospital', 'pllc', 'fifth', 'world', 'pop', 'estate', 'sample', 'icon', 'electric', 'community', 'books', 'factory', 'ms', 'run', 'ltd', 'jersey', 'attorney', 'island', 'science', 'bar', 'on', 'halloween', 'smoke', 'lab', 'social', 'senior', 'chicken', 'general', 'architecture', 'cleaning', 'young', 'playground', 'living', 'elizabeth', 'japanese', 'communications', 'home', 'out', 'spring', 'to', 'trade', 'fashion', 'men', 'palace', 'morgan', 'agency', 'style', 'media', 'light', 'gold', 'lic', 'meat', 'pro', 'vintage', 'project', 'city', 'place ...
# {'little', 'center', 'river', 'hill', 'washington', 'heights', 'chelsea', 'george', 'upper', 'harlem', 'gramercy', 'hudson', 'empire', 'brooklyn', 'times', 'two', 'square', 'theater', 'station', 'west', 'east', 'hell', 'financial', 'madison', 'soho', 'murray', 'midtown', 'astoria', 'drive', 'street', 'union', 'central', 'fort', 'north', 'park', 'tribeca', 'wall', 'south', 'riverside', 'bowery', 'queens', 'district', 'greenpoint', 'bryant', 'side', 'columbia', 'williamsburg'}
